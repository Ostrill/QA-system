# %%
# !nvidia-smi
# Out:
# Tue May 28 09:38:46 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Импорт библиотек

# %%
import torch
from transformers import AutoModelForQuestionAnswering
from transformers import AutoTokenizer
from datasets import load_dataset
from transformers import DefaultDataCollator
from transformers import TrainingArguments, Trainer
from transformers import pipeline
import copy
import string
import numpy as np
from mealpy import FloatVar, DE

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cuda'

# %% [markdown]
# # Подготовка

# %% [markdown]
# ## Инициализация модели

# %%
tokenizer = AutoTokenizer.from_pretrained('ai-forever/ruBert-base')
# Out:
# config.json:   0%|          | 0.00/590 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.78M [00:00<?, ?B/s]

# %%
model = AutoModelForQuestionAnswering.from_pretrained('ai-forever/ruBert-base').to(DEVICE)
# Out:
# pytorch_model.bin:   0%|          | 0.00/716M [00:00<?, ?B/s]

# %% [markdown]
# ## Загрузка набора данных SberQuAD

# %%
sberquad = load_dataset('sberquad')
sberquad
# Out:
# Downloading builder script:   0%|          | 0.00/4.22k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/4.96k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.84M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.93M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/45328 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5036 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/23936 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 45328
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 5036
#     })
#     test: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 23936
#     })
# })

# %%
# Функция для обработки набора данных
def preprocess_function(examples):
    # Тексты вопросов
    questions = [q.strip() for q in examples['question']]
    # Тексты контекстов
    contexts = [c.strip() for c in examples['context']]

    # Входы для модели
    inputs = tokenizer(
        questions,
        contexts,
        max_length=256,
        truncation='only_second',
        padding='max_length',
        return_offsets_mapping=True,
        return_tensors='pt',
    )

    offset_mapping = inputs.pop('offset_mapping')
    answers = examples['answers']
    start_positions = []
    end_positions = []

    # Поиск стартовых и конечных позиций ответов
    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer['answer_start'][0]
        end_char = answer['answer_start'][0] + len(answer['text'][0])
        sequence_ids = inputs.sequence_ids(i)

        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # Если ответ не полностью внутри контекста, отметить начало и конец за (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs['start_positions'] = start_positions
    inputs['end_positions'] = end_positions

    return inputs

# %%
# Размеры мини-выборок из SberQuAD для алгоритма дифференциальной эволюции
mini_train_size = 1000
mini_valid_size = 500

# %%
# Перемешанный датасет
shuffled = sberquad.shuffle(seed=2209)

# Мини-выборка для оптимизации гиперпараметров
mini_sberquad_train = shuffled['train'].select(range(mini_train_size))
mini_sberquad_valid = shuffled['validation'].select(range(mini_valid_size))

# %%
# Преобразование набора обучающих данных в эмбеддинги
mini_sberquad_train = mini_sberquad_train.map(preprocess_function,
                                              batched=True,
                                              remove_columns=mini_sberquad_train.column_names)
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# Извлечение правильных ответов из валидационной выборки
validation_answers = [answer['text'][0]
                      for answer in mini_sberquad_valid['answers']]

# %% [markdown]
# ## Метрики для модели

# %%
# Нормализация текста: убрать лишние пробелы и знаки пунктуации
def normalize_text(s):
    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        for exclude in string.punctuation:
            text = text.replace(exclude, ' ')
        return text

    return white_space_fix(remove_punc(s.lower()))

# Метрика F1 для текста
def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    if len(common_tokens) == 0:
        return 0

    precision = len(common_tokens) / len(pred_tokens)
    recall = len(common_tokens) / len(truth_tokens)

    return 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# ## Фитнес-функция для DE

# %%
def main_fitness(x):
    # Интерпретация входа в виде гиперпараметров
    b1, b2, lr, wd = x

    # Создание копии модели
    agent_model = copy.deepcopy(model)

    # Конфигурация процесса обучения
    training_args = TrainingArguments(
        output_dir='/tmp',
        save_strategy='no',
        per_device_train_batch_size=16,
        num_train_epochs=1,
        learning_rate=lr,
        weight_decay=wd,
        adam_beta1=b1,
        adam_beta2=b2,
        seed=2209,
        data_seed=2209,
        disable_tqdm=True
    )

    # Инициализация объекта для обучения модели
    trainer = Trainer(
        model=agent_model,
        args=training_args,
        train_dataset=mini_sberquad_train,
        tokenizer=tokenizer,
        data_collator=DefaultDataCollator(),
    )

    # Запуск процесса обучения
    trainer.train()

    # Инициализация интерфейса для вопросно-ответной модели
    qa_pipeline = pipeline('question-answering',
                           model=agent_model,
                           tokenizer=tokenizer)

    # Ответы модели на валидационном датасете
    predicted_answers = qa_pipeline(question=mini_sberquad_valid['question'],
                                    context=mini_sberquad_valid['context'])

    # Расчет F1-меры для всех объектов валидационной выборки
    f1_results = [compute_f1(pred['answer'], truth)
                  for pred, truth in zip(predicted_answers,
                                         validation_answers)]

    # Средняя оценка F1 по всей валидационной выборке
    mean_f1 = np.mean(f1_results)
    print(' > f1:', mean_f1, f'{(b1, b2, lr, wd)}')

    return mean_f1

# %% [markdown]
# # Дифференциальная эволюция

# %%
# %%time

# Диапазоны подбора значений
bounds = [
    (0.6, 0.9999), # beta 1
    (0.8, 0.9999), # beta 2
    (1e-6, 1e-2),  # learning rate
    (0, 1e-1),     # weight decay
]

# Описание задачи оптимизации
problem_dict = {
    'bounds': FloatVar(lb=[bound[0] for bound in bounds],
                       ub=[bound[1] for bound in bounds]),
    'minmax': 'max',
    'obj_func': main_fitness
}

# Инициализация алгоритма DE
optimizer = DE.OriginalDE(epoch=4, pop_size=20,
                          wf=0.5, cr=0.7,
                          strategy=1,
                          seed=2209)

# Запуск алгоритма
g_best = optimizer.solve(problem_dict)
print('Solution:', g_best.solution)
print('Fitness:', g_best.target.fitness)
# Out:
# {'train_runtime': 104.8789, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 6.275709364149305, 'epoch': 1.0}
# INFO:mealpy.evolutionary_based.DE.OriginalDE:Solving single objective optimization problem.
#  > f1: 0.059465483209600864 (0.9638203315824687, 0.8742710057963523, 0.008931552823505962, 0.0021755370536997386)
# {'train_runtime': 104.2727, 'train_samples_per_second': 9.59, 'train_steps_per_second': 0.604, 'train_loss': 6.248460557725695, 'epoch': 1.0}
#  > f1: 0.052273983532807065 (0.926354082787163, 0.8885127042835124, 0.006316421553765208, 0.08756622387324167)
# {'train_runtime': 104.7103, 'train_samples_per_second': 9.55, 'train_steps_per_second': 0.602, 'train_loss': 6.259676009889633, 'epoch': 1.0}
#  > f1: 0.056651187340351426 (0.8128740067738456, 0.9557988402385269, 0.008015630846131758, 0.031196286481969416)
# {'train_runtime': 104.242, 'train_samples_per_second': 9.593, 'train_steps_per_second': 0.604, 'train_loss': 6.257745167565724, 'epoch': 1.0}
#  > f1: 0.059781213087775203 (0.8469139894323805, 0.8993003290467253, 0.008254092229627367, 0.006310777471731544)
# {'train_runtime': 104.5871, 'train_samples_per_second': 9.561, 'train_steps_per_second': 0.602, 'train_loss': 6.2565496535528276, 'epoch': 1.0}
#  > f1: 0.0734333539250567 (0.8728554915265418, 0.8653674903236563, 0.0032633123433420982, 0.09013343803120696)
# {'train_runtime': 104.4136, 'train_samples_per_second': 9.577, 'train_steps_per_second': 0.603, 'train_loss': 6.259438166542659, 'epoch': 1.0}
#  > f1: 0.07733865435218376 (0.6100247074957077, 0.8019255896672961, 0.0027373308241240746, 0.0025946060839553533)
# {'train_runtime': 104.5461, 'train_samples_per_second': 9.565, 'train_steps_per_second': 0.603, 'train_loss': 6.252215673053075, 'epoch': 1.0}
#  > f1: 0.06741615685655933 (0.9238795120391621, 0.9794654947657646, 0.004406429830398732, 0.06875768386230409)
# {'train_runtime': 104.664, 'train_samples_per_second': 9.554, 'train_steps_per_second': 0.602, 'train_loss': 3.9157511393229165, 'epoch': 1.0}
#  > f1: 0.3567030685001273 (0.9825771429410347, 0.8652910460707327, 0.0006906883698542241, 0.039405800479665076)
# {'train_runtime': 104.5792, 'train_samples_per_second': 9.562, 'train_steps_per_second': 0.602, 'train_loss': 6.257369268508184, 'epoch': 1.0}
#  > f1: 0.07250648161035159 (0.737675898680165, 0.8033286342204349, 0.0028778864708355295, 0.08286521208110548)
# {'train_runtime': 104.4851, 'train_samples_per_second': 9.571, 'train_steps_per_second': 0.603, 'train_loss': 6.253994411892361, 'epoch': 1.0}
#  > f1: 0.062146876264430446 (0.607210241159512, 0.9851915528805426, 0.0050738665348696406, 0.007662478819513263)
# {'train_runtime': 104.4565, 'train_samples_per_second': 9.573, 'train_steps_per_second': 0.603, 'train_loss': 6.244597419859871, 'epoch': 1.0}
#  > f1: 0.06012874579242866 (0.8606350146204573, 0.8829349644284041, 0.0016946658706605406, 0.07326474894377659)
# {'train_runtime': 104.4543, 'train_samples_per_second': 9.574, 'train_steps_per_second': 0.603, 'train_loss': 6.25159418015253, 'epoch': 1.0}
#  > f1: 0.05495178187227589 (0.9239202961295454, 0.9730222138388613, 0.005744554022060701, 0.00684191603194182)
# {'train_runtime': 104.2556, 'train_samples_per_second': 9.592, 'train_steps_per_second': 0.604, 'train_loss': 6.25848873077877, 'epoch': 1.0}
#  > f1: 0.06357260509356484 (0.8515686917243251, 0.8462494953708454, 0.005623502572548, 0.047708527113328805)
# {'train_runtime': 104.3707, 'train_samples_per_second': 9.581, 'train_steps_per_second': 0.604, 'train_loss': 6.246853298611111, 'epoch': 1.0}
#  > f1: 0.06454004976193696 (0.6760546656519913, 0.8535682923800171, 0.0016915482547388454, 0.05562937354385791)
# {'train_runtime': 104.3505, 'train_samples_per_second': 9.583, 'train_steps_per_second': 0.604, 'train_loss': 6.268199617900546, 'epoch': 1.0}
#  > f1: 0.05924784891750837 (0.7057918156320415, 0.8665086474602667, 0.009258615143649073, 0.07453128327540787)
# {'train_runtime': 104.6376, 'train_samples_per_second': 9.557, 'train_steps_per_second': 0.602, 'train_loss': 6.252334352523562, 'epoch': 1.0}
#  > f1: 0.050079240275585676 (0.8216511242679897, 0.8708405593000998, 0.0061337252097522854, 0.00707649128291914)
# {'train_runtime': 104.3179, 'train_samples_per_second': 9.586, 'train_steps_per_second': 0.604, 'train_loss': 6.243723551432292, 'epoch': 1.0}
#  > f1: 0.06707463685265543 (0.6896487044052296, 0.9535417752842033, 0.0015174494667763213, 0.06880819730173766)
# {'train_runtime': 104.5308, 'train_samples_per_second': 9.567, 'train_steps_per_second': 0.603, 'train_loss': 6.254076760912699, 'epoch': 1.0}
#  > f1: 0.05831386804891315 (0.8214015081580053, 0.9087926501469995, 0.007030137580185194, 0.08510379336188517)
# {'train_runtime': 104.7011, 'train_samples_per_second': 9.551, 'train_steps_per_second': 0.602, 'train_loss': 6.2592352004278276, 'epoch': 1.0}
#  > f1: 0.07414273141808611 (0.9371469969692141, 0.9521773605610164, 0.003002726153758734, 0.09016431686630615)
# {'train_runtime': 104.3218, 'train_samples_per_second': 9.586, 'train_steps_per_second': 0.604, 'train_loss': 6.257983010912699, 'epoch': 1.0}
#  > f1: 0.06857878416732906 (0.8939435288946946, 0.8602583804102754, 0.0031245758067011626, 0.008616014903777548)
# {'train_runtime': 104.2462, 'train_samples_per_second': 9.593, 'train_steps_per_second': 0.604, 'train_loss': 6.257846408420139, 'epoch': 1.0}
#  > f1: 0.07273653840916865 (0.9535614038531713, 0.8988041678248213, 0.003306525741123264, 0.08650857164775409)
# {'train_runtime': 105.1303, 'train_samples_per_second': 9.512, 'train_steps_per_second': 0.599, 'train_loss': 6.141155908978175, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.8894753362615362, 0.8, 1e-06, 0.04645956458906577)
# {'train_runtime': 104.6971, 'train_samples_per_second': 9.551, 'train_steps_per_second': 0.602, 'train_loss': 3.4541853647383434, 'epoch': 1.0}
#  > f1: 0.5541026891409244 (0.9999, 0.9557988402385269, 0.00016779708516160956, 0.031196286481969416)
# {'train_runtime': 104.5239, 'train_samples_per_second': 9.567, 'train_steps_per_second': 0.603, 'train_loss': 6.2458917526971724, 'epoch': 1.0}
#  > f1: 0.06527246787701761 (0.8392104990734435, 0.8993003290467253, 0.0016653337339384631, 0.038929032437532936)
# {'train_runtime': 105.1273, 'train_samples_per_second': 9.512, 'train_steps_per_second': 0.599, 'train_loss': 6.141454787481399, 'epoch': 1.0}
#  > f1: 0.0816634764444362 (0.9999, 0.8962722519958817, 1e-06, 0.09013343803120696)
# {'train_runtime': 104.5722, 'train_samples_per_second': 9.563, 'train_steps_per_second': 0.602, 'train_loss': 6.226714603484623, 'epoch': 1.0}
#  > f1: 0.06987661689875313 (0.6100247074957077, 0.8081155492805113, 0.0012206177072955466, 0.0025946060839553533)
# {'train_runtime': 104.4939, 'train_samples_per_second': 9.57, 'train_steps_per_second': 0.603, 'train_loss': 6.25258043077257, 'epoch': 1.0}
#  > f1: 0.07691406990670148 (0.9238795120391621, 0.9501378358799459, 0.00212402214546681, 0.06875768386230409)
# {'train_runtime': 104.4887, 'train_samples_per_second': 9.57, 'train_steps_per_second': 0.603, 'train_loss': 6.259061298673115, 'epoch': 1.0}
#  > f1: 0.06449010701552228 (0.9825771429410347, 0.8799874023917406, 0.0031437230947082397, 0.027638896648437)
# {'train_runtime': 104.7268, 'train_samples_per_second': 9.549, 'train_steps_per_second': 0.602, 'train_loss': 6.2588709271143355, 'epoch': 1.0}
#  > f1: 0.07395829525479682 (0.9532487195352901, 0.9191566299547971, 0.003217621195957463, 0.02312385825580345)
# {'train_runtime': 104.8485, 'train_samples_per_second': 9.538, 'train_steps_per_second': 0.601, 'train_loss': 5.031404041108631, 'epoch': 1.0}
#  > f1: 0.18631534535296146 (0.607210241159512, 0.9851915528805426, 1.586217904686821e-05, 0.02059984506978095)
# {'train_runtime': 105.0865, 'train_samples_per_second': 9.516, 'train_steps_per_second': 0.6, 'train_loss': 6.1412866985987105, 'epoch': 1.0}
#  > f1: 0.0816634764444362 (0.9999, 0.8829349644284041, 1e-06, 0.07326474894377659)
# {'train_runtime': 104.8981, 'train_samples_per_second': 9.533, 'train_steps_per_second': 0.601, 'train_loss': 4.420934283544147, 'epoch': 1.0}
#  > f1: 0.2555956109250227 (0.9239202961295454, 0.9730222138388613, 0.0009752858283538189, 0.08136278326156444)
# {'train_runtime': 103.8883, 'train_samples_per_second': 9.626, 'train_steps_per_second': 0.606, 'train_loss': 6.280830988808284, 'epoch': 1.0}
#  > f1: 0.053230547774416395 (0.9912385714705174, 0.9105449431546297, 0.005623502572548, 0.035301043480817244)
# {'train_runtime': 104.9367, 'train_samples_per_second': 9.53, 'train_steps_per_second': 0.6, 'train_loss': 3.8167036752852184, 'epoch': 1.0}
#  > f1: 0.4161449499142069 (0.952924547620737, 0.8358419212984718, 0.000644165675226074, 0.05562937354385791)
# {'train_runtime': 104.6086, 'train_samples_per_second': 9.559, 'train_steps_per_second': 0.602, 'train_loss': 6.212455144004216, 'epoch': 1.0}
#  > f1: 0.060072432085495765 (0.7057918156320415, 0.853848857091275, 0.0012650565284107198, 0.07453128327540787)
# {'train_runtime': 104.7526, 'train_samples_per_second': 9.546, 'train_steps_per_second': 0.601, 'train_loss': 3.7557765415736606, 'epoch': 1.0}
#  > f1: 0.5489581056198704 (0.9332863557047699, 0.9309623939653665, 6.609119517229835e-05, 0.012440081376851618)
# {'train_runtime': 105.102, 'train_samples_per_second': 9.515, 'train_steps_per_second': 0.599, 'train_loss': 6.141382610987103, 'epoch': 1.0}
#  > f1: 0.0816634764444362 (0.9999, 0.8903024243832509, 1e-06, 0.060618255938604156)
# {'train_runtime': 103.7285, 'train_samples_per_second': 9.641, 'train_steps_per_second': 0.607, 'train_loss': 6.256517682756696, 'epoch': 1.0}
#  > f1: 0.05747754105289574 (0.9999, 0.9087926501469995, 0.007030137580185194, 0.06978726957555682)
# {'train_runtime': 104.4833, 'train_samples_per_second': 9.571, 'train_steps_per_second': 0.603, 'train_loss': 6.260503859747024, 'epoch': 1.0}
#  > f1: 0.060510260718028924 (0.9999, 0.9521773605610164, 0.003002726153758734, 0.05233566023930748)
# {'train_runtime': 104.5466, 'train_samples_per_second': 9.565, 'train_steps_per_second': 0.603, 'train_loss': 6.25958251953125, 'epoch': 1.0}
#  > f1: 0.0603752187390241 (0.9999, 0.9124643772350255, 0.0031245758067011626, 0.08317521645329087)
# {'train_runtime': 104.4119, 'train_samples_per_second': 9.577, 'train_steps_per_second': 0.603, 'train_loss': 6.256444053044395, 'epoch': 1.0}
# INFO:mealpy.evolutionary_based.DE.OriginalDE:>>>Problem: P, Epoch: 1, Current best: 0.5541026891409244, Global best: 0.5541026891409244, Runtime: 2268.85452 seconds
#  > f1: 0.06978370662705027 (0.9535614038531713, 0.8988041678248213, 0.003306525741123264, 0.06349488776054135)
# {'train_runtime': 105.1329, 'train_samples_per_second': 9.512, 'train_steps_per_second': 0.599, 'train_loss': 6.14208742171999, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.9506092127637353, 0.9999, 1e-06, 0.004230567379155958)
# {'train_runtime': 104.6699, 'train_samples_per_second': 9.554, 'train_steps_per_second': 0.602, 'train_loss': 3.4324137369791665, 'epoch': 1.0}
#  > f1: 0.5692116687749815 (0.9849116163825746, 0.899416923524234, 0.00016779708516160956, 0.031196286481969416)
# {'train_runtime': 105.0801, 'train_samples_per_second': 9.517, 'train_steps_per_second': 0.6, 'train_loss': 4.920389811197917, 'epoch': 1.0}
#  > f1: 0.159429206981529 (0.9999, 0.9999, 2.2911735133159124e-05, 0.03461203647504771)
# {'train_runtime': 105.0291, 'train_samples_per_second': 9.521, 'train_steps_per_second': 0.6, 'train_loss': 6.141455271887401, 'epoch': 1.0}
#  > f1: 0.0816634764444362 (0.9999, 0.8962722519958817, 1e-06, 0.04994348532336977)
# {'train_runtime': 104.5496, 'train_samples_per_second': 9.565, 'train_steps_per_second': 0.603, 'train_loss': 6.258475167410714, 'epoch': 1.0}
#  > f1: 0.07343492845303992 (0.8270428467693876, 0.8019255896672961, 0.0027373308241240746, 0.013681522244930935)
# {'train_runtime': 104.6327, 'train_samples_per_second': 9.557, 'train_steps_per_second': 0.602, 'train_loss': 3.8369879344153026, 'epoch': 1.0}
#  > f1: 0.41877111420832647 (0.9619101480647727, 0.9501378358799459, 0.000654939999338519, 0.06875768386230409)
# {'train_runtime': 104.3085, 'train_samples_per_second': 9.587, 'train_steps_per_second': 0.604, 'train_loss': 6.251494876922123, 'epoch': 1.0}
#  > f1: 0.0947105748293674 (0.9825771429410347, 0.9108591125036916, 0.001402614988842931, 0.0011254520027061433)
# {'train_runtime': 104.5644, 'train_samples_per_second': 9.563, 'train_steps_per_second': 0.602, 'train_loss': 6.259849427238343, 'epoch': 1.0}
#  > f1: 0.07135844766949896 (0.9332285376708753, 0.9292151261618327, 0.002895649828854805, 0.03945240679764911)
# {'train_runtime': 104.6125, 'train_samples_per_second': 9.559, 'train_steps_per_second': 0.602, 'train_loss': 6.259228903149801, 'epoch': 1.0}
#  > f1: 0.06569627779259224 (0.9257343458621625, 0.8789735879239495, 0.00296809250386903, 0.02059984506978095)
# {'train_runtime': 104.6635, 'train_samples_per_second': 9.554, 'train_steps_per_second': 0.602, 'train_loss': 3.47176760718936, 'epoch': 1.0}
#  > f1: 0.5655080552858248 (0.9999, 0.908354275989881, 0.00016036599563817546, 0.07326474894377659)
# {'train_runtime': 105.0594, 'train_samples_per_second': 9.518, 'train_steps_per_second': 0.6, 'train_loss': 6.1417962937127974, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.9999, 0.9288660482964948, 1e-06, 0.08136278326156444)
# {'train_runtime': 104.2029, 'train_samples_per_second': 9.597, 'train_steps_per_second': 0.605, 'train_loss': 6.257661849733383, 'epoch': 1.0}
#  > f1: 0.05872277084202646 (0.8515686917243251, 0.9444947812507842, 0.005623502572548, 0.047708527113328805)
# {'train_runtime': 105.1938, 'train_samples_per_second': 9.506, 'train_steps_per_second': 0.599, 'train_loss': 6.140565902467758, 'epoch': 1.0}
#  > f1: 0.08199680977776955 (0.9999, 0.8358419212984718, 1e-06, 0.0002063189289285526)
# {'train_runtime': 105.1052, 'train_samples_per_second': 9.514, 'train_steps_per_second': 0.599, 'train_loss': 6.142093234592014, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.9852357882971277, 0.982731632180559, 1e-06, 0.07453128327540787)
# {'train_runtime': 104.8707, 'train_samples_per_second': 9.536, 'train_steps_per_second': 0.601, 'train_loss': 3.5130755712115573, 'epoch': 1.0}
#  > f1: 0.5407988908610123 (0.9999, 0.9309177581784999, 0.000494767084830869, 0.012440081376851618)
# {'train_runtime': 104.9365, 'train_samples_per_second': 9.53, 'train_steps_per_second': 0.6, 'train_loss': 3.3980308411613342, 'epoch': 1.0}
#  > f1: 0.5734745570391081 (0.9999, 0.9055573020006439, 0.0002511956277424143, 0.044679146033376145)
# {'train_runtime': 104.696, 'train_samples_per_second': 9.551, 'train_steps_per_second': 0.602, 'train_loss': 3.4230232844277033, 'epoch': 1.0}
#  > f1: 0.5522257503792031 (0.9999, 0.9087926501469995, 0.00036141957645015354, 0.08510379336188517)
# {'train_runtime': 104.7383, 'train_samples_per_second': 9.548, 'train_steps_per_second': 0.601, 'train_loss': 3.8543613978794644, 'epoch': 1.0}
#  > f1: 0.4045079701904712 (0.9999, 0.9497141707176863, 0.0006475089098150849, 0.06157775557786116)
# {'train_runtime': 104.9751, 'train_samples_per_second': 9.526, 'train_steps_per_second': 0.6, 'train_loss': 3.204926263718378, 'epoch': 1.0}
#  > f1: 0.6364740886564416 (0.8939435288946946, 0.8602583804102754, 0.00031546127580053715, 0.06752814247448619)
# {'train_runtime': 104.7946, 'train_samples_per_second': 9.542, 'train_steps_per_second': 0.601, 'train_loss': 3.3740430559430803, 'epoch': 1.0}
# INFO:mealpy.evolutionary_based.DE.OriginalDE:>>>Problem: P, Epoch: 2, Current best: 0.6364740886564416, Global best: 0.6364740886564416, Runtime: 2271.38098 seconds
#  > f1: 0.6178667945401691 (0.9535614038531713, 0.8988041678248213, 0.00016036599563817546, 0.04586810660876382)
# {'train_runtime': 105.0481, 'train_samples_per_second': 9.519, 'train_steps_per_second': 0.6, 'train_loss': 6.142616393074157, 'epoch': 1.0}
#  > f1: 0.08271961679531338 (0.7180008086101621, 0.8, 1e-06, 0.004230567379155958)
# {'train_runtime': 105.0665, 'train_samples_per_second': 9.518, 'train_steps_per_second': 0.6, 'train_loss': 6.141673738994296, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.9319333808299219, 0.8736972734908447, 1e-06, 0.04415276908122782)
# {'train_runtime': 104.9263, 'train_samples_per_second': 9.53, 'train_steps_per_second': 0.6, 'train_loss': 3.2631763276599703, 'epoch': 1.0}
#  > f1: 0.6176674567262803 (0.874948602927081, 0.8809309732767485, 0.0004622214872447199, 0.03461203647504771)
# {'train_runtime': 104.8637, 'train_samples_per_second': 9.536, 'train_steps_per_second': 0.601, 'train_loss': 3.2504420204768105, 'epoch': 1.0}
#  > f1: 0.6101291392503938 (0.9012756347461308, 0.8230697023149364, 0.0003951442736196249, 0.04994348532336977)
# {'train_runtime': 104.8475, 'train_samples_per_second': 9.538, 'train_steps_per_second': 0.601, 'train_loss': 3.411683824327257, 'epoch': 1.0}
#  > f1: 0.6122886381935918 (0.9477577989016714, 0.8524384168072674, 0.00042969471710528926, 0.0025946060839553533)
# {'train_runtime': 104.8328, 'train_samples_per_second': 9.539, 'train_steps_per_second': 0.601, 'train_loss': 3.3188609774150546, 'epoch': 1.0}
#  > f1: 0.6243854050833927 (0.9619101480647727, 0.8180468180867986, 0.00033705100582010676, 0.06875768386230409)
# {'train_runtime': 105.0387, 'train_samples_per_second': 9.52, 'train_steps_per_second': 0.6, 'train_loss': 6.141586545913938, 'epoch': 1.0}
#  > f1: 0.08206347644443619 (0.9681091830325321, 0.8899122837251746, 1e-06, 0.039405800479665076)
# {'train_runtime': 104.7405, 'train_samples_per_second': 9.547, 'train_steps_per_second': 0.601, 'train_loss': 3.2694212898375494, 'epoch': 1.0}
#  > f1: 0.6496933720390378 (0.8023061158267103, 0.9191566299547971, 0.00011838913899072471, 0.04467168350237928)
# {'train_runtime': 104.8742, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 3.2511742001488093, 'epoch': 1.0}
#  > f1: 0.6318997590644649 (0.9129384548623083, 0.9056312964403759, 0.00032764556111556053, 0.07570119722427673)
# {'train_runtime': 104.9061, 'train_samples_per_second': 9.532, 'train_steps_per_second': 0.601, 'train_loss': 3.2161736866784474, 'epoch': 1.0}
#  > f1: 0.6494955795838148 (0.8997749389527834, 0.9015391774729951, 0.00028171191954850497, 0.07326474894377659)
# {'train_runtime': 104.6611, 'train_samples_per_second': 9.555, 'train_steps_per_second': 0.602, 'train_loss': 3.378238980732267, 'epoch': 1.0}
#  > f1: 0.6226000063575914 (0.9239202961295454, 0.9400893453430867, 0.00011838913899072471, 0.07982204145050523)
# {'train_runtime': 104.7453, 'train_samples_per_second': 9.547, 'train_steps_per_second': 0.601, 'train_loss': 3.6674652099609375, 'epoch': 1.0}
#  > f1: 0.5251629057217293 (0.8515686917243251, 0.8015380873553621, 0.0006603054607276492, 0.04996540107661479)
# {'train_runtime': 105.0115, 'train_samples_per_second': 9.523, 'train_steps_per_second': 0.6, 'train_loss': 3.1550477043030756, 'epoch': 1.0}
#  > f1: 0.6577179747325258 (0.86344786876818, 0.8805945913197017, 0.00029075730271509474, 0.0918410199587541)
# {'train_runtime': 105.0801, 'train_samples_per_second': 9.517, 'train_steps_per_second': 0.6, 'train_loss': 3.2870340498666915, 'epoch': 1.0}
#  > f1: 0.6085698400267118 (0.9564192274311542, 0.982731632180559, 0.00020994834604938435, 0.0725616972536504)
# {'train_runtime': 104.8897, 'train_samples_per_second': 9.534, 'train_steps_per_second': 0.601, 'train_loss': 3.8108673095703125, 'epoch': 1.0}
#  > f1: 0.5380587339732851 (0.7951465868080498, 0.9309623939653665, 5.0901390388357064e-05, 0.059075106436745246)
# {'train_runtime': 105.1043, 'train_samples_per_second': 9.514, 'train_steps_per_second': 0.599, 'train_loss': 3.1995677645244296, 'epoch': 1.0}
#  > f1: 0.6435971742911372 (0.8707742308212802, 0.9055573020006439, 0.0002149344853945481, 0.04791029909792551)
# {'train_runtime': 104.8744, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 3.2994503445095487, 'epoch': 1.0}
#  > f1: 0.6055630343714407 (0.9585064134840545, 0.8823368147687966, 0.00036141957645015354, 0.074361870714454)
# {'train_runtime': 104.8158, 'train_samples_per_second': 9.541, 'train_steps_per_second': 0.601, 'train_loss': 3.4687318347749256, 'epoch': 1.0}
#  > f1: 0.6128684720792138 (0.9035462984431721, 0.9497141707176863, 9.277578813398659e-05, 0.06157775557786116)
# {'train_runtime': 104.6983, 'train_samples_per_second': 9.551, 'train_steps_per_second': 0.602, 'train_loss': 3.18176027328249, 'epoch': 1.0}
#  > f1: 0.6467717159001989 (0.871837778665445, 0.8602583804102754, 0.00031546127580053715, 0.0970197172214391)
# {'train_runtime': 104.9552, 'train_samples_per_second': 9.528, 'train_steps_per_second': 0.6, 'train_loss': 3.2040322924417164, 'epoch': 1.0}
# INFO:mealpy.evolutionary_based.DE.OriginalDE:>>>Problem: P, Epoch: 3, Current best: 0.6577179747325258, Global best: 0.6577179747325258, Runtime: 2273.89300 seconds
#  > f1: 0.6446827137430853 (0.845209117331658, 0.8690671066511764, 0.00023379988552164703, 0.04586810660876382)
# {'train_runtime': 104.8447, 'train_samples_per_second': 9.538, 'train_steps_per_second': 0.601, 'train_loss': 6.142793201264881, 'epoch': 1.0}
#  > f1: 0.08329104536674195 (0.7180008086101621, 0.8922418321554915, 1e-06, 0.004230567379155958)
# {'train_runtime': 104.8771, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 3.296231224423363, 'epoch': 1.0}
#  > f1: 0.6414382057399084 (0.8794532292474996, 0.9345409371449168, 0.00012623076349143147, 0.031196286481969416)
# {'train_runtime': 104.9033, 'train_samples_per_second': 9.533, 'train_steps_per_second': 0.601, 'train_loss': 3.292572990296379, 'epoch': 1.0}
#  > f1: 0.6379613236952246 (0.874948602927081, 0.8864182117375966, 0.00014587865135754738, 0.04803579366895503)
# {'train_runtime': 104.8971, 'train_samples_per_second': 9.533, 'train_steps_per_second': 0.601, 'train_loss': 3.196628873310392, 'epoch': 1.0}
#  > f1: 0.6451835502474821 (0.7849739716097206, 0.8835064015286491, 0.0003951442736196249, 0.06993840681385456)
# {'train_runtime': 104.7214, 'train_samples_per_second': 9.549, 'train_steps_per_second': 0.602, 'train_loss': 3.3079150971912203, 'epoch': 1.0}
#  > f1: 0.6213806926475657 (0.9020214254785747, 0.8882867449147616, 0.00042969471710528926, 0.08510332144854917)
# {'train_runtime': 104.824, 'train_samples_per_second': 9.54, 'train_steps_per_second': 0.601, 'train_loss': 3.2284732394748263, 'epoch': 1.0}
#  > f1: 0.6374881290050491 (0.8644914617946302, 0.8303971826138206, 0.00036649291791547936, 0.0927411066891559)
# {'train_runtime': 105.017, 'train_samples_per_second': 9.522, 'train_steps_per_second': 0.6, 'train_loss': 3.3164818173363093, 'epoch': 1.0}
#  > f1: 0.6353776786852638 (0.8642103052504788, 0.8652910460707327, 0.0001222978382294434, 0.0800782370234101)
# {'train_runtime': 104.8739, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 3.2747017996651784, 'epoch': 1.0}
#  > f1: 0.648679512506757 (0.8023061158267103, 0.8496469476626067, 0.00011838913899072471, 0.04467168350237928)
# {'train_runtime': 104.8485, 'train_samples_per_second': 9.538, 'train_steps_per_second': 0.601, 'train_loss': 3.1478758312406994, 'epoch': 1.0}
#  > f1: 0.6614949757500842 (0.8205477391624002, 0.8695691410837043, 0.00032764556111556053, 0.1)
# {'train_runtime': 104.7257, 'train_samples_per_second': 9.549, 'train_steps_per_second': 0.602, 'train_loss': 3.3339327857607888, 'epoch': 1.0}
#  > f1: 0.6001130664828807 (0.8967452288254822, 0.9015391774729951, 0.00042333789626910687, 0.08185451709013422)
# {'train_runtime': 104.7615, 'train_samples_per_second': 9.545, 'train_steps_per_second': 0.601, 'train_loss': 3.29293459937686, 'epoch': 1.0}
#  > f1: 0.6358663677739529 (0.8699092538033326, 0.895024138948931, 0.00014385103130900982, 0.1)
# {'train_runtime': 104.6072, 'train_samples_per_second': 9.56, 'train_steps_per_second': 0.602, 'train_loss': 3.7018248542906744, 'epoch': 1.0}
#  > f1: 0.5532116969373935 (0.8777467165262256, 0.9122425708097466, 0.0006603054607276492, 0.04996540107661479)
# {'train_runtime': 104.8204, 'train_samples_per_second': 9.54, 'train_steps_per_second': 0.601, 'train_loss': 3.211365957108755, 'epoch': 1.0}
#  > f1: 0.6454696834125626 (0.86344786876818, 0.9307920000255829, 0.00021502168751471015, 0.0918410199587541)
# {'train_runtime': 104.7504, 'train_samples_per_second': 9.547, 'train_steps_per_second': 0.601, 'train_loss': 3.1755843389601934, 'epoch': 1.0}
#  > f1: 0.6590010918733828 (0.8191492889278191, 0.886938253409769, 0.00018197303014452288, 0.0725616972536504)
# {'train_runtime': 104.7438, 'train_samples_per_second': 9.547, 'train_steps_per_second': 0.601, 'train_loss': 3.6331290593222967, 'epoch': 1.0}
#  > f1: 0.5531030719478693 (0.8205477391624002, 0.8695691410837043, 6.609119517229835e-05, 0.012440081376851618)
# {'train_runtime': 104.9954, 'train_samples_per_second': 9.524, 'train_steps_per_second': 0.6, 'train_loss': 3.3058631533668157, 'epoch': 1.0}
#  > f1: 0.6435422061254878 (0.790202542175946, 0.9115169160905372, 0.00010801084375735507, 0.04758575030375413)
# {'train_runtime': 104.6726, 'train_samples_per_second': 9.554, 'train_steps_per_second': 0.602, 'train_loss': 3.3275282118055554, 'epoch': 1.0}
#  > f1: 0.640963320820906 (0.8604933998377897, 0.8823368147687966, 0.00011833521025153871, 0.074361870714454)
# {'train_runtime': 104.8227, 'train_samples_per_second': 9.54, 'train_steps_per_second': 0.601, 'train_loss': 3.222348167782738, 'epoch': 1.0}
#  > f1: 0.6317523624810003 (0.8596401434771528, 0.843453312952381, 0.0003853725588696476, 0.06157775557786116)
# {'train_runtime': 104.908, 'train_samples_per_second': 9.532, 'train_steps_per_second': 0.601, 'train_loss': 3.2093377491784474, 'epoch': 1.0}
#  > f1: 0.6465075940571297 (0.8256881546541455, 0.8811793846996281, 0.00042916183439913784, 0.0970197172214391)
# {'train_runtime': 104.8786, 'train_samples_per_second': 9.535, 'train_steps_per_second': 0.601, 'train_loss': 3.1759849427238342, 'epoch': 1.0}
# INFO:mealpy.evolutionary_based.DE.OriginalDE:>>>Problem: P, Epoch: 4, Current best: 0.6614949757500842, Global best: 0.6614949757500842, Runtime: 2270.57097 seconds
#  > f1: 0.6522898873744075 (0.8427758133131947, 0.8690671066511764, 0.00032257621266158684, 0.04586810660876382)
# Solution: [8.20547739e-01 8.69569141e-01 3.27645561e-04 1.00000000e-01]
# Fitness: 0.6614949757500842
# CPU times: user 3h 9min 20s, sys: 51.3 s, total: 3h 10min 11s
# Wall time: 3h 11min 1s

# %%
# Вывод найденных значений гиперпараметров
[print(f'{name:>13} = {val}')
 for name, val in zip(('beta_1', 'beta_2', 'learning_rate', 'weight_decay'),
                      g_best.solution)];
# Out:
#        beta_1 = 0.8205477391624002
#        beta_2 = 0.8695691410837043
# learning_rate = 0.00032764556111556053
#  weight_decay = 0.1
